# %% [markdown]
# ถบเเถวซ้ำ

# %%
import pandas as pd

# อ่านไฟล์ Excel
df = pd.read_excel('data/data.xlsx')

# ตรวจสอบค่าซ้ำโดยพิจารณาคอลัมน์เหล่านี้ร่วมกัน
duplicate_rows = df[df.duplicated(subset=['มหาวิทยาลัย', 'คณะ', 'หลักสูตร', 'ลิงก์'])]

# แสดงแถวที่ซ้ำ
print("แถวที่ซ้ำกัน:")
print(duplicate_rows[['มหาวิทยาลัย', 'หลักสูตร']])

# ลบแถวที่ซ้ำ (โดยเก็บแถวแรกไว้)
df_no_duplicates = df.drop_duplicates(subset=['มหาวิทยาลัย', 'คณะ', 'หลักสูตร', 'ลิงก์'], keep='first')

# บันทึกเป็นไฟล์ใหม่
df_no_duplicates.to_excel('data/data_drop_duplicates.xlsx', index=False)

print("บันทึกไฟล์เรียบร้อย")
# Out:
# แถวที่ซ้ำกัน:
#                                       มหาวิทยาลัย  \
# 34               มหาวิทยาลัยสงขลานครินทร์ หาดใหญ่
# 36                มหาวิทยาลัยสงขลานครินทร์ ภูเก็ต
# 50                          มหาวิทยาลัยวลัยลักษณ์
# 71      มหาวิทยาลัยเทคโนโลยีราชมงคลศรีวิชัย สงขลา
# 76                         มหาวิทยาลัยหอการค้าไทย
# 77                     มหาวิทยาลัยเทคโนโลยีมหานคร
# 82  สถาบันการจัดการปัญญาภิวัฒน์ แจ้งวัฒนะ นนทบุรี
#
#                                              หลักสูตร
# 34                        วศ.บ. วิศวกรรมปัญญาประดิษฐ์
# 36         วศ.บ. วิศวกรรมปัญญาประดิษฐ์และระบบอัจฉริยะ
# 50  วิศวกรรมศาสตรบัณฑิต สาขาวิศวกรรมคอมพิวเตอร์และ...
# 71      วศ.บ. วิศวกรรมปัญญาประดิษฐ์และนวัตกรรมดิจิทัล
# 76  หลักสูตรวิศวกรรมศาสตรบัณฑิต (วิศวกรรมคอมพิวเตอ...
# 77          วศ.บ. วิศวกรรมคอมพิวเตอร์และปัญญาประดิษฐ์
# 82  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# บันทึกไฟล์เรียบร้อย

# %% [markdown]
# กรองเเถวออก ตามเงื่อนไข

# %%
import pandas as pd

# อ่านไฟล์ Excel
df = pd.read_excel('data/data_drop_duplicates.xlsx')

# เงื่อนไขกรองหลักสูตรที่เกี่ยวข้อง
condition1 = (
    (df['หลักสูตร'].astype(str).str.contains('วิศวกรรม')) &
    (
        df['หลักสูตร'].astype(str).str.contains('คอมพิวเตอร์') |
        df['หลักสูตร'].astype(str).str.contains('ปัญญาประดิษฐ์')
    )
)

# เงื่อนไขกรองคณะที่ไม่ต้องการ
condition2 = ~(
    df['คณะ'].astype(str).str.contains('> วิศวกรรมทั่วไป') |
    df['หลักสูตร'].astype(str).str.contains('ครุศาสตร์') |
    df['หลักสูตร'].astype(str).str.contains('ค.อ.บ.') |
    df['หลักสูตร'].astype(str).str.contains('อส.บ.')
)

# รวมเงื่อนไขทั้งสอง
final_condition = condition1 & condition2

# กรองข้อมูล
filtered_df = df[final_condition]

# แสดงรายการที่ถูกตัดออก (optional)
dropped_df = df[~final_condition]
print("\n📌 หลักสูตรที่ถูกตัดออก:")
for _, row in dropped_df.iterrows():
    print([row['หลักสูตร']])

# บันทึกไฟล์ใหม่
filtered_df.to_excel('data/filtered_data.xlsx', index=False)
print("\n✅ บันทึกไฟล์เรียบร้อย")
# Out:
# 📌 หลักสูตรที่ถูกตัดออก:
# ['หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมระบบอัจฉริยะ ปริญญาตรี 4 ปี (พื้นที่การศึกษาราชบุรี)']
# ['หลักสูตรวิทยาศาสตรบัณฑิต สาขาวิชาเทคโนโลยีสารสนเทศและปัญญาประดิษฐ์']
# ['วท.บ. สาขาวิชาวิทยาการคอมพิวเตอร์']
# ['วศ.บ.วิศวกรรมระบบสารสนเทศและเครือข่าย']
# ['วศ.บ. วิศวกรรมดิจิทัล (หลักสูตรนานาชาติ)']
# ['ครุศาสตร์อุตสาหกรรมบัณฑิต สาขาวิชาวิศวกรรมไฟฟ้า ปริญญาตรี 5 ปี']
# ['วศ.บ.เทคโนโลยีวิศวกรรมอิเล็กทรอนิกส์']
# ['วศ.บ.เทคโนโลยีวิศวกรรมอิเล็กทรอนิกส์']
# ['กลุ่มวิศวกรรมศาสตร์ (ประกอบด้วยสาขาวิชาวิศวกรรมการผลิตอัตโนมัติและหุ่นยนต์, วิศวกรรมเกษตรและอาหาร, วิศวกรรมคอมพิวเตอร์, วิศวกรรมเคมี, วิศวกรรมเครื่องกล, วิศวกรรมปิโตรเลียมและเทคโนโลยีธรณี, วิศวกรรมไฟฟ้า, วิศวกรรมโทรคมนาคม, วิศวกรรมยานยนต์,วิศวกรรมโยธา, วิศวกรรมขนส่งและโลจิสติส์, วิศวกรรมเซรามิก, วิศวกรรมพอลิเมอร์, วิศวกรรมโลหการ, วิศวกรรมสิ่งแวดล้อม, วิศวกรรมธรณี, วิศวกรรมอากาศยาน, วิศวกรรมอิเล็กทรอนิกส์, วิศวกรรมอุตสาหการ เรียนรวมกันปี 1 แยกสาขาปี 2)']
# ['วิศวกรรมศาสตรบัณฑิต']
# ['วท.บ.วิศวกรรมซอฟต์แวร์']
# ['อส.บ. เทคโนโลยีวิศวกรรมคอมพิวเตอร์ 4 ปี']
# ['ค.อ.บ.วิศวกรรมไฟฟ้า']
#
# ✅ บันทึกไฟล์เรียบร้อย

# %% [markdown]
# กรองค่าเทอม

# %%
import pandas as pd
import re

# โหลดข้อมูล
df = pd.read_excel('data/filtered_data.xlsx')

# สร้างฟังก์ชันสำหรับดึงค่าเทอม
def extract_tuition(text):
    text = str(text)
    
    # ข้าม URL หรือ "ไม่พบข้อมูล"
    if 'http' in text or 'ไม่พบข้อมูล' in text:
        return None

    # ค้นหาตัวเลข เช่น 30000, 232,000, 105,000 ฯลฯ
    numbers = re.findall(r'\d{2,3}(?:,\d{3})*|\d+', text)
    numbers = [int(n.replace(',', '')) for n in numbers if int(n.replace(',', '')) >= 1000]

    # ตรวจคำว่า "ต่อภาคการศึกษา", "ต่อภาคเรียน", "ตลอดหลักสูตร"
    if 'ตลอดหลักสูตร' in text:
        term = 'ตลอดหลักสูตร'
    elif 'ต่อภาค' in text or '/เทอม' in text or '/ภาค' in text:
        term = 'ต่อภาคการศึกษา'
    else:
        term = 'ไม่ชัดเจน'

    # ส่งค่าเทอมที่มากที่สุด (มักจะเป็นค่าเทอมหลัก)
    if numbers:
        return f"{max(numbers):,} บาท {term}"
    else:
        return None

# ประมวลผลคอลัมน์ "ค่าใช้จ่าย"
df['ค่าเทอมที่ดึงได้'] = df['ค่าใช้จ่าย'].apply(extract_tuition)

# แสดงเฉพาะที่ดึงค่าเทอมได้
print(df[['มหาวิทยาลัย', 'หลักสูตร', 'ค่าเทอมที่ดึงได้']].dropna())

# บันทึกข้อมูลลงไฟล์ใหม่
df.to_excel('data/tuition.xlsx', index=False)

print("✅ บันทึกไฟล์ tuition.xlsx แล้วเรียบร้อย")
# Out:
#                                           มหาวิทยาลัย  \
# 2                   มหาวิทยาลัยเชียงใหม่ วิทยาเขตหลัก
# 3                    มหาวิทยาลัยสงขลานครินทร์ หาดใหญ่
# 4                     มหาวิทยาลัยสงขลานครินทร์ ภูเก็ต
# 5   สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 6   สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 7   สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 8                 มหาวิทยาลัยอุบลราชธานี วิทยาเขตหลัก
# 9                               มหาวิทยาลัยวลัยลักษณ์
# 10          มหาวิทยาลัยเทคโนโลยีราชมงคลศรีวิชัย สงขลา
# 11           มหาวิทยาลัยเทคโนโลยีราชมงคลอีสาน ขอนแก่น
# 12                             มหาวิทยาลัยหอการค้าไทย
# 14      สถาบันการจัดการปัญญาภิวัฒน์ แจ้งวัฒนะ นนทบุรี
# 18                    มหาวิทยาลัยเกษตรศาสตร์ กำแพงแสน
# 19                     มหาวิทยาลัยเกษตรศาสตร์ ศรีราชา
# 22                  มหาวิทยาลัยเชียงใหม่ วิทยาเขตหลัก
# 23                  มหาวิทยาลัยธรรมศาสตร์ ศูนย์รังสิต
# 24                  มหาวิทยาลัยธรรมศาสตร์ ศูนย์รังสิต
# 25                            มหาวิทยาลัยมหิดล ศาลายา
# 26                      มหาวิทยาลัยศิลปากร สนามจันทร์
# 27                      มหาวิทยาลัยศิลปากร สนามจันทร์
# 28                มหาวิทยาลัยศรีนครินทรวิโรฒ องครักษ์
# 29                   มหาวิทยาลัยสงขลานครินทร์ หาดใหญ่
# 32  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ กรุ...
# 33  สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 34  สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 35  สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 36  สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง...
# 37           มหาวิทยาลัยเทคโนโลยีสุรนารี วิทยาเขตหลัก
# 38                     มหาวิทยาลัยนเรศวร วิทยาเขตหลัก
# 39                              มหาวิทยาลัยแม่ฟ้าหลวง
# 40                     มหาวิทยาลัยนราธิวาสราชนครินทร์
# 42                  มหาวิทยาลัยกาฬสินธุ์ วิทยาเขตหลัก
# 43                                มหาวิทยาลัยรามคำแหง
# 44                                มหาวิทยาลัยรามคำแหง
# 45                             สถาบันเทคโนโลยีจิตรลดา
# 46                            มหาวิทยาลัยราชภัฏพระนคร
# 47                       มหาวิทยาลัยราชภัฏพิบูลสงคราม
# 49          มหาวิทยาลัยราชภัฏอุบลราชธานี วิทยาเขตหลัก
# 54     มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์ ศาลายา
# 55          มหาวิทยาลัยเทคโนโลยีราชมงคลศรีวิชัย สงขลา
# 56           มหาวิทยาลัยเทคโนโลยีราชมงคลศรีวิชัย ตรัง
# 57        มหาวิทยาลัยเทคโนโลยีราชมงคลอีสาน นครราชสีมา
# 59                                  มหาวิทยาลัยรังสิต
# 61             มหาวิทยาลัยเกษมบัณฑิต วิทยาเขตร่มเกล้า
# 62                       มหาวิทยาลัยสยาม วิทยาเขตหลัก
#
#                                              หลักสูตร  \
# 2               วศ.บ.วิศวกรรมหุ่นยนต์และปัญญาประดิษฐ์
# 3                         วศ.บ. วิศวกรรมปัญญาประดิษฐ์
# 4          วศ.บ. วิศวกรรมปัญญาประดิษฐ์และระบบอัจฉริยะ
# 5   วศ.บ. วิศวกรรมหุ่นยนต์และปัญญาประดิษฐ์ (หลักสู...
# 6   วศ.บ. วิศวกรรมปัญญาประดิษฐ์และการเป็นผู้ประกอบ...
# 7   วศ.บ. เทคโนโลยีวัสดุชาญฉลาด วศ.บ.วิศวกรรมหุ่นย...
# 8     วศ.บ.สาขาวิชาวิศวกรรมปัญญาประดิษฐ์และการสั่งการ
# 9   วิศวกรรมศาสตรบัณฑิต สาขาวิศวกรรมคอมพิวเตอร์และ...
# 10      วศ.บ. วิศวกรรมปัญญาประดิษฐ์และนวัตกรรมดิจิทัล
# 11  วศ.บ.วิศวกรรมเครื่องกล-ระบบอัตโนมัติ หุ่นยนต์ ...
# 12  หลักสูตรวิศวกรรมศาสตรบัณฑิต (วิศวกรรมคอมพิวเตอ...
# 14  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 18                  วศ.บ. สาขาวิชาวิศวกรรมคอมพิวเตอร์
# 19  วศ.บ. สาขาวิชาวิศวกรรมคอมพิวเตอร์และสารสนเทศศา...
# 22                           วศ.บ.วิศวกรรมคอมพิวเตอร์
# 23                   วศ.บ.สาขาวิชาวิศวกรรมคอมพิวเตอร์
# 24  วศ.บ.สาขาวิชาวิศวกรรมดิจิทัล และวิศวกรรมคอมพิว...
# 25  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 26  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมอิ...
# 27  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมอิ...
# 28  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 29                          วศ.บ. วิศวกรรมคอมพิวเตอร์
# 32                           วศ.บ.วิศวกรรมคอมพิวเตอร์
# 33                          วศ.บ. วิศวกรรมคอมพิวเตอร์
# 34       วศ.บ. วิศวกรรมคอมพิวเตอร์ (หลักสูตรนานาชาติ)
# 35     วศ.บ. วิศวกรรมคอมพิวเตอร์และความปลอดภัยไซเบอร์
# 36                          วศ.บ. วิศวกรรมคอมพิวเตอร์
# 37                                วิศวกรรมคอมพิวเตอร์
# 38  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 39  วศ.บ. วิศวกรรมคอมพิวเตอร์ (จัดการเรียนการสอนเป...
# 40                                วิศวกรรมคอมพิวเตอร์
# 42                          วศ.บ. วิศวกรรมคอมพิวเตอร์
# 43  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 44  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 45    วิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอมพิวเตอร์
# 46  วศ.บ. 4 ปี วิศวกรรมอิเล็กทรอนิกส์อัจฉริยะและคอ...
# 47  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 49               วศ.บ.วิศวกรรมคอมพิวเตอร์และเครือข่าย
# 54                     วศ.บ. วิศวกรรมคอมพิวเตอร์ 4 ปี
# 55                          วศ.บ. วิศวกรรมคอมพิวเตอร์
# 56             วศ.บ. วิศวกรรมคอมพิวเตอร์และการสื่อสาร
# 57                           วศ.บ.วิศวกรรมคอมพิวเตอร์
# 59                           วศ.บ.วิศวกรรมคอมพิวเตอร์
# 61                           วศ.บ.วิศวกรรมคอมพิวเตอร์
# 62                  วศ.บ. สาขาวิชาวิศวกรรมคอมพิวเตอร์
#
#               ค่าเทอมที่ดึงได้
# 2        232,000 บาท ไม่ชัดเจน
# 3    28,000 บาท ต่อภาคการศึกษา
# 4     228,000 บาท ตลอดหลักสูตร
# 5   105,000 บาท ต่อภาคการศึกษา
# 6   175,000 บาท ต่อภาคการศึกษา
# 7   120,000 บาท ต่อภาคการศึกษา
# 8     224,000 บาท ตลอดหลักสูตร
# 9    32,700 บาท ต่อภาคการศึกษา
# 10       110,000 บาท ไม่ชัดเจน
# 11     96,000 บาท ตลอดหลักสูตร
# 12    340,000 บาท ตลอดหลักสูตร
# 14    384,000 บาท ตลอดหลักสูตร
# 18       156,000 บาท ไม่ชัดเจน
# 19       232,800 บาท ไม่ชัดเจน
# 22       184,000 บาท ไม่ชัดเจน
# 23   18,900 บาท ต่อภาคการศึกษา
# 24  101,200 บาท ต่อภาคการศึกษา
# 25   30,000 บาท ต่อภาคการศึกษา
# 26       152,000 บาท ไม่ชัดเจน
# 27       280,000 บาท ไม่ชัดเจน
# 28    200,000 บาท ตลอดหลักสูตร
# 29   18,000 บาท ต่อภาคการศึกษา
# 32   25,000 บาท ต่อภาคการศึกษา
# 33   25,000 บาท ต่อภาคการศึกษา
# 34   90,000 บาท ต่อภาคการศึกษา
# 35   50,000 บาท ต่อภาคการศึกษา
# 36   20,000 บาท ต่อภาคการศึกษา
# 37       197,100 บาท ไม่ชัดเจน
# 38   16,000 บาท ต่อภาคการศึกษา
# 39    224,000 บาท ตลอดหลักสูตร
# 40       112,000 บาท ไม่ชัดเจน
# 42   10,150 บาท ต่อภาคการศึกษา
# 43        33,000 บาท ไม่ชัดเจน
# 44    403,260 บาท ตลอดหลักสูตร
# 45    252,000 บาท ตลอดหลักสูตร
# 46     96,000 บาท ตลอดหลักสูตร
# 47   12,000 บาท ต่อภาคการศึกษา
# 49        72,610 บาท ไม่ชัดเจน
# 54   15,000 บาท ต่อภาคการศึกษา
# 55       110,000 บาท ไม่ชัดเจน
# 56       110,000 บาท ไม่ชัดเจน
# 57    152,000 บาท ตลอดหลักสูตร
# 59    396,800 บาท ตลอดหลักสูตร
# 61    282,000 บาท ตลอดหลักสูตร
# 62    303,500 บาท ตลอดหลักสูตร
# ✅ บันทึกไฟล์ tuition.xlsx แล้วเรียบร้อย

# %% [markdown]
# ค่าเทอม

# %%
import pandas as pd
import re

# โหลดไฟล์ที่มีคอลัมน์ "ค่าเทอมที่ดึงได้"
df = pd.read_excel('data/tuition.xlsx')

# ฟังก์ชันแปลงค่าเทอมเป็นตัวเลขต่อภาค
def estimate_per_term(text):
    if pd.isna(text):
        return None

    text = str(text)

    # ค้นหาเลขจากข้อความ เช่น "120,000 บาท ตลอดหลักสูตร"
    match = re.search(r'(\d{1,3}(?:,\d{3})*|\d+)', text)
    if match:
        amount = int(match.group(1).replace(',', ''))
    else:
        return None

    # คำนวณ
    if 'ตลอดหลักสูตร' in text:
        estimated = amount // 8
    elif 'ต่อภาค' in text:
        estimated = amount
    else:
        estimated = None

    return estimated

# สร้างคอลัมน์ใหม่ "ค่าเทอม"
df['ค่าเทอม'] = df['ค่าเทอมที่ดึงได้'].apply(estimate_per_term)

# แสดงผล
# กรองเฉพาะแถวที่เป็น "ตลอดหลักสูตร"
mask = df['ค่าเทอมที่ดึงได้'].astype(str).str.contains('ตลอดหลักสูตร', na=False)
# แสดงผลเฉพาะคอลัมน์ที่ต้องการ
print(df.loc[mask, ['ค่าเทอมที่ดึงได้', 'ค่าเทอม']])


# บันทึกไฟล์ใหม่
df.to_excel('data/data-cleaned.xlsx', index=False)
print("✅ บันทึกไฟล์ final-data.xlsx แล้วเรียบร้อย")
# Out:
#             ค่าเทอมที่ดึงได้  ค่าเทอม
# 12  340,000 บาท ตลอดหลักสูตร    42500
# 13  348,575 บาท ตลอดหลักสูตร    43571
# 14  384,000 บาท ตลอดหลักสูตร    48000
# 28  200,000 บาท ตลอดหลักสูตร    25000
# 37  197,100 บาท ตลอดหลักสูตร    24637
# 44  403,260 บาท ตลอดหลักสูตร    50407
# 49  72,610  บาท ตลอดหลักสูตร     9076
# 57  152,000 บาท ตลอดหลักสูตร    19000
# 58  373,600 บาท ตลอดหลักสูตร    46700
# 59  396,800 บาท ตลอดหลักสูตร    49600
# 60  337,000 บาท ตลอดหลักสูตร    42125
# 61  282,000 บาท ตลอดหลักสูตร    35250
# 62  303,500 บาท ตลอดหลักสูตร    37937
# ✅ บันทึกไฟล์ final-data.xlsx แล้วเรียบร้อย

# %%
import pandas as pd

# อ่านไฟล์
df = pd.read_excel("data/data-cleaned.xlsx")  # ← เปลี่ยน path ตรงนี้

# ลบคอลัมน์ที่ไม่ต้องการ
df.drop(columns=["ลิงก์", "ค่าใช้จ่าย", "ค่าเทอมที่ดึงได้"], inplace=True, errors='ignore')

# ฟังก์ชันจัดหมวดหมู่ประเภทหลักสูตร
def normalize_course_type(course_type):
    course_type = str(course_type).strip()

    if "Double Degree" in course_type:
        return "นานาชาติ พิเศษ"
    elif "Joint Degree" in course_type:
        return "นานาชาติ"
    elif "นานาชาติ" in course_type:
        return "นานาชาติ"
    elif "พิเศษ" in course_type:
        return "ภาษาไทย พิเศษ"
    else:
        return "ภาษาไทย ปกติ"

# แปลงข้อมูลในคอลัมน์ 'ประเภทหลักสูตร'
df['ประเภทหลักสูตร'] = df['ประเภทหลักสูตร'].apply(normalize_course_type)

# แยก "คณะ > สาขา" → คณะหลัก และ สาขา
df[['คณะ', 'สาขา']] = df['คณะ'].str.split('>', n=1, expand=True)

# ล้างช่องว่างหัวท้าย
df['คณะ'] = df['คณะ'].str.strip()

# กรณีบางแถวไม่มี ">" จะไม่มีสาขา ต้องเติมให้เป็นค่าว่างหรือ "ไม่ระบุ"
df['สาขา'] = df['สาขา'].fillna('ไม่ระบุ').str.strip()

# กำหนดลำดับคอลัมน์ที่ต้องการใหม่นิดหน่อย
cols = list(df.columns)

# เอาคอลัมน์ 'คณะ' กับ 'สาขา' ไปอยู่ติดกันที่ตำแหน่งที่ 2 กับ 3
# สมมติคอลัมน์แรกคือ 'ประเภทหลักสูตร' อยู่ตำแหน่ง 0

# เอาคอลัมน์ 'คณะ' กับ 'สาขา' ออกก่อน (ถ้ามี)
for col in ['คณะ', 'สาขา']:
    if col in cols:
        cols.remove(col)

# แทรก 'คณะ' กับ 'สาขา' เข้าไปที่ตำแหน่ง 1 และ 2 (index เริ่ม 0)
cols.insert(2, 'คณะ')
cols.insert(3, 'สาขา')

# จัดลำดับ dataframe ตาม cols ที่แก้แล้ว
df = df[cols]


# บันทึกผลลัพธ์
df.to_excel("data/cleaned_file.xlsx", index=False)  # ← ตั้งชื่อไฟล์ใหม่ตามต้องการ

print("✅ ทำความสะอาดข้อมูลและแปลงประเภทหลักสูตรเรียบร้อย")
# Out:
# ✅ ทำความสะอาดข้อมูลและแปลงประเภทหลักสูตรเรียบร้อย

# %% [markdown]
# ภาค

# %%
import pandas as pd

# โหลดจากไฟล์ Excel
df = pd.read_excel("data/cleaned_file.xlsx")

def get_region(university_name):
    name = university_name.lower()

    # ตรวจสอบภาคที่มีชื่อเฉพาะเจาะจงที่อาจทับซ้อนก่อน
    # ภาคตะวันออก
    if 'เกษตรศาสตร์ ศรีราชา' in name:
        return 'ตะวันออก'

    # ภาคใต้
    elif 'เจ้าคุณทหารลาดกระบัง ชุมพร' in name:
        return 'ใต้'
    elif 'ราชมงคลศรีวิชัย ตรัง' in name:
        return 'ใต้'

    # ภาคตะวันออกเฉียงเหนือ
    elif 'เกษตรศาสตร์ เฉลิมพระเกียรติ จ.สกลนคร' in name:
        return 'ตะวันออกเฉียงเหนือ'
    elif any(x in name for x in [
        'ขอนแก่น', 'อุบลราชธานี', 'เทคโนโลยีสุรนารี', 'กาฬสินธุ์',
        'ราชภัฏอุบลราชธานี', 'ราชมงคลอีสาน'
    ]):
        return 'ตะวันออกเฉียงเหนือ'

    # ภาคใต้ (ต่อจากชื่อเฉพาะด้านบน)
    elif any(x in name for x in [
        'สงขลา', 'ภูเก็ต', 'วลัยลักษณ์', 'นราธิวาสราชนครินทร์',
        'ราชมงคลศรีวิชัย'
    ]):
        return 'ใต้'

    # ภาคเหนือ
    elif any(x in name for x in [
        'เชียงใหม่', 'นเรศวร', 'แม่ฟ้าหลวง', 'พะเยา', 'ราชภัฏพิบูลสงคราม'
    ]):
        return 'เหนือ'

    # ภาคกลาง (ตรวจสอบเป็นลำดับสุดท้ายสำหรับชื่อที่อาจทับซ้อนหรือไม่เฉพาะเจาะจงมากพอ)
    elif any(x in name for x in [
        'จุฬาลงกรณ์', 'ธรรมศาสตร์', 'มหิดล', 'ศิลปากร สนามจันทร์',
        'ศรีนครินทรวิโรฒ องครักษ์', 'เกษตรศาสตร์ บางเขน', 'เกษตรศาสตร์ กำแพงแสน',
        'พระจอมเกล้าธนบุรี', 'พระจอมเกล้าพระนครเหนือ', 'เจ้าคุณทหารลาดกระบัง ลาดกระบัง',
        'หอการค้าไทย', 'มหานคร', 'ปัญญาภิวัฒน์', 'รามคำแหง', 'จิตรลดา',
        'ราชภัฏพระนคร', 'สวนสุนันทา', 'ราชมงคลธัญบุรี', 'ราชมงคลกรุงเทพ',
        'ราชมงคลพระนคร', 'ราชมงคลรัตนโกสินทร์', 'ศรีปทุม', 'รังสิต', 'ธุรกิจบัณฑิตย์',
        'เกษมบัณฑิต', 'สยาม', 'ราชมงคลรัตนโกสินทร์ ศาลายา'
    ]):
        return 'กลาง'

    return 'ไม่ทราบภาค'

# สร้างคอลัมน์ 'ภาค'
df['ภาค'] = df['มหาวิทยาลัย'].apply(get_region)

# บันทึกผลลัพธ์
df.to_excel("data/cleaned_with_region.xlsx", index=False)

print("✅ เพิ่มคอลัมน์ 'ภาค' เรียบร้อยแล้ว")
# Out:
# ✅ เพิ่มคอลัมน์ 'ภาค' เรียบร้อยแล้ว

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# อ่านไฟล์ Excel
df = pd.read_excel("data/cleaned_with_region.xlsx")

# สร้าง geolocator
geolocator = Nominatim(user_agent="my_geocoder")
# ตั้ง RateLimiter เพื่อกันถูกบล็อกจากการขอข้อมูลเร็วเกินไป
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# ฟังก์ชันเพื่อตัดคำ "วิทยาเขตหลัก" ออกจากชื่อมหาวิทยาลัย (ถ้ามี)
def clean_university_name(name):
    if "วิทยาเขตหลัก" in name:
        return name.replace("วิทยาเขตหลัก", "").strip()
    return name

# ฟังก์ชันเพื่อค้นหาพิกัดจากชื่อมหาวิทยาลัย
def get_lat_lon(university_name):
    try:
        clean_name = clean_university_name(university_name)
        location = geocode(clean_name + ", Thailand")
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except:
        return None, None

# สร้างคอลัมน์ใหม่สำหรับ Lat และ Lon
df[['Latitude', 'Longitude']] = df['มหาวิทยาลัย'].apply(lambda x: pd.Series(get_lat_lon(x)))

# บันทึกเป็นไฟล์ใหม่
df.to_excel("data/university_fee_with_latlon1.xlsx", index=False)

print(df[['มหาวิทยาลัย', 'Latitude', 'Longitude']])
# Out:
#                                มหาวิทยาลัย   Latitude   Longitude
# 0                    จุฬาลงกรณ์มหาวิทยาลัย  13.743111  100.532875
# 1               มหาวิทยาลัยขอนแก่น ขอนแก่น  16.459187  102.811993
# 2        มหาวิทยาลัยเชียงใหม่ วิทยาเขตหลัก  18.800926   98.952155
# 3         มหาวิทยาลัยสงขลานครินทร์ หาดใหญ่   7.006959  100.500760
# 4          มหาวิทยาลัยสงขลานครินทร์ ภูเก็ต   7.894153   98.352946
# ..                                     ...        ...         ...
# 58                      มหาวิทยาลัยศรีปทุม  13.854758  100.585453
# 59                       มหาวิทยาลัยรังสิต  13.966509  100.584230
# 60               มหาวิทยาลัยธุรกิจบัณฑิตย์  13.870249  100.550720
# 61  มหาวิทยาลัยเกษมบัณฑิต วิทยาเขตร่มเกล้า  13.802668  100.736574
# 62            มหาวิทยาลัยสยาม วิทยาเขตหลัก  13.720837  100.453467
#
# [63 rows x 3 columns]

# %%
import plotly.express as px

fig = px.scatter_map(df, 
                     lat="Latitude", 
                     lon="Longitude", 
                     hover_name="มหาวิทยาลัย",
                     hover_data=["คณะ", "ค่าเทอม"],
                     color="ภาค",
                     size="ค่าเทอม", 
                     size_max=15, 
                     zoom=5)

fig.show()
